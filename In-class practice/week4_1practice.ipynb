# %% [markdown]
# ### Lecture 4 Practice: Class

# %% [markdown]
# ### Question 1
# Create a Rectangle class with the following specifications:
# Represents a rectangle whoses sides are parallel to the x and y axes. Specified by its upper-left corner, height, and width.
#
# Add an area() method to return the area of the rectangle.

# %%
class Point():
    name = "I am a Point class data attibute"
    def __init__(self, xval, yval):
        
        self.x = xval
        self.y = yval
        
    def __str__(self):
        return f"Point({self.x}, {self.y})"  
        
    def distance(self, other_point):
        x_diff_square = (self.x - other_point.x) ** 2
        y_diff_square = (self.y - other_point.y) ** 2
        return (x_diff_square + y_diff_square) ** 0.5

# %%
p1 = Point(1, 2)
p2 = Point(3, 4)
p1.distance(p2)
# Out:
# 2.8284271247461903

# %%
class Rectangle():
    def __init__(self, upperleft, height, width):
        self.corner = upperleft
        self.h = height
        self.w = width

    def __str__(self):
        return f"Rectangle with corner at {self.corner}, height {self.h}, width {self.w}"
    
    def area(self):
        return self.h * self.w

# %%
upper_left_corner = Point(0,0)
my_rectangle = Rectangle(upper_left_corner, 4, 4)
print(my_rectangle)
print(my_rectangle.area())
# Out:
# Rectangle with corner at Point(0, 0), height 4, width 4
# 16
