# %% [markdown]
# # STATS 507, Week 1 practice

# %%
def my_add(x,y):
    return x+y
print(my_add(3,4))
# Out:
# 7

# %%
import torch

map_lanes = torch.cat([
    torch.randn(2,11,48,100,5).float(),
    torch.randn(2,11,48,100,1).float(),
    torch.randint(0, 11, (2, 11, 48, 100, 1)).int(),
    torch.randint(0, 11, (2, 11,48,100, 1)).int(),
], dim=-1)

# %% [markdown]
# ### Problem 1
# Write a Python function that prints "Hello, World!".

# %%
def fun():
    print("Hello, World!")

fun
# Out:
# Hello World!

# %% [markdown]
# ### Problem 2
# Write a function that takes two integers as argumens. Return the first argument if it is a positive number. Otherwise, return the sum of both arguments.

# %%
def postive_or_sum(x, y):
    if x > 0: 
        return x
    else:
        return x+y

assert postive_or_sum(1,2) == 1

# %%
assert postive_or_sum(42, 16) == 42
assert postive_or_sum(33, 13) == 33
assert postive_or_sum(-33, 13) == -20

# %%
assert postive_or_sum(3, 4) == 3

# %%
assertEqual
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 assertEqual
#
# NameError: name 'assertEqual' is not defined
